# %% [markdown]
# 개선사항
#
# Autogluon으로 모델 찾기
#
# 하이퍼파라미터 찾기 GridSearch
#
# 임계점 찾기
#
# 스케일링
#
# from supervised.automl import AutoML

# %%
# !pip install mljar-supervised
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.7/112.7 KB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 MB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.5/90.5 KB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.4/572.4 KB 47.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 KB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.3/365.3 KB 36.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 25.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 KB 10.5 MB/s eta 0:00:00
# ...
#   Created wheel for mljar-supervised: filename=mljar_supervised-0.11.5-py3-none-any.whl size=147060 sha256=0380617815355141187b7d18099d980ee4a22051e9cf039cf17c787961d47cbb
# ...

# %%
from supervised.automl import AutoML
from sklearn.cluster import KMeans
import pandas as pd
import random
import os
#
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(99)

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Data Load

# %%
path = '/content/gdrive/MyDrive/phone_cancel'
train = pd.read_csv(f'{path}/train.csv')
test = pd.read_csv(f'{path}/test.csv')
#using Autogluno

# %%
train.head()
# Out:
#             ID  가입일  음성사서함이용  주간통화시간  주간통화횟수  주간통화요금  저녁통화시간  저녁통화횟수  저녁통화요금  \
# 0  TRAIN_00000  329        0    99.2      93    27.3   268.8      68   28.92
# 1  TRAIN_00001    2       80   323.9     323    83.7   269.4     326   32.09
# 2  TRAIN_00002   93       28   282.4     323    34.2   207.0     322   32.82
# 3  TRAIN_00003  223        1   221.4     223    25.1   233.0      61   23.90
# 4  TRAIN_00004  222        0    96.3     222    28.7   223.9      69   28.08
#
#    밤통화시간  밤통화횟수  밤통화요금  상담전화건수  전화해지여부
# 0  262.9    328  32.89       2       0
# 1  322.8    209  32.32       2       0
# 2  280.8    328   8.28       0       0
# 3  203.8    234   9.36       0       0
# 4  263.1    223   2.80       8       0

# %%
test.head()
# Out:
#            ID  가입일  음성사서함이용  주간통화시간  주간통화횟수  주간통화요금  저녁통화시간  저녁통화횟수  저녁통화요금  \
# 0  TEST_00000  110        0   210.7     142    35.6   205.9      93   17.43
# 1  TEST_00001  283        1   268.5     100    30.3   283.0      92   28.32
# 2  TEST_00002   34        1   243.3     205    21.3   225.7     205   29.00
# 3  TEST_00003  209       86    83.0      93    24.1   270.6     220   22.89
# 4  TEST_00004  202        0   293.2      23    31.0   294.0      24   26.39
#
#    밤통화시간  밤통화횟수  밤통화요금  상담전화건수
# 0  120.9    111   5.37       2
# 1  290.0     89   8.82       0
# 2   92.6     29   2.44       2
# 3  266.9     81   2.80       6
# 4  223.8     33   6.66       2

# %%
train

# %%
y_train = train['전화해지여부']
train = train.drop(['ID','전화해지여부'], axis=1)
test = test.drop('ID', axis=1)

# %%
kmeans = KMeans(n_clusters=5, random_state=123)
kmeans.fit(train)

train['kmeans_basic'] = kmeans.labels_
test['kmeans_basic'] = kmeans.predict(test)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %%
train.head()
# Out:
#    가입일  음성사서함이용  주간통화시간  주간통화횟수  주간통화요금  저녁통화시간  저녁통화횟수  저녁통화요금  밤통화시간  밤통화횟수  \
# 0  329        0    99.2      93    27.3   268.8      68   28.92  262.9    328
# 1    2       80   323.9     323    83.7   269.4     326   32.09  322.8    209
# 2   93       28   282.4     323    34.2   207.0     322   32.82  280.8    328
# 3  223        1   221.4     223    25.1   233.0      61   23.90  203.8    234
# 4  222        0    96.3     222    28.7   223.9      69   28.08  263.1    223
#
#    밤통화요금  상담전화건수  kmeans_basic
# 0  32.89       2             0
# 1  32.32       2             4
# 2   8.28       0             4
# 3   9.36       0             0
# 4   2.80       8             0

# %%
train['총통화횟수'] = train['주간통화횟수']+train['저녁통화횟수']+train['밤통화횟수']
test['총통화횟수'] = test['주간통화횟수']+test['저녁통화횟수']+test['밤통화횟수']

train['총통화시간'] = train['주간통화시간']+train['저녁통화시간']+train['밤통화시간']
test['총통화시간'] = test['주간통화시간']+test['저녁통화시간']+test['밤통화시간']

train['총통화요금'] = train['주간통화요금']+train['저녁통화요금']+train['밤통화요금']
test['총통화요금'] = test['주간통화요금']+test['저녁통화요금']+test['밤통화요금']

# %%
train.head()
# Out:
#    가입일  음성사서함이용  주간통화시간  주간통화횟수  주간통화요금  저녁통화시간  저녁통화횟수  저녁통화요금  밤통화시간  밤통화횟수  \
# 0  329        0    99.2      93    27.3   268.8      68   28.92  262.9    328
# 1    2       80   323.9     323    83.7   269.4     326   32.09  322.8    209
# 2   93       28   282.4     323    34.2   207.0     322   32.82  280.8    328
# 3  223        1   221.4     223    25.1   233.0      61   23.90  203.8    234
# 4  222        0    96.3     222    28.7   223.9      69   28.08  263.1    223
#
#    밤통화요금  상담전화건수  kmeans_basic  총통화횟수  총통화시간   총통화요금
# 0  32.89       2             0    489  630.9   89.11
# 1  32.32       2             4    858  916.1  148.11
# 2   8.28       0             4    973  770.2   75.30
# 3   9.36       0             0    518  658.2   58.36
# 4   2.80       8             0    514  583.3   59.58

# %% [markdown]
# AutoML

# %%
X = train.drop(['ID','전화해지여부'],axis=1)
y = train['전화해지여부'].loc[:]

# %%
automl = AutoML(mode='Compete', eval_metric='f1')

# %%
automl.fit(train, y_train)
# Out:
# Linear algorithm was disabled.
# AutoML directory: AutoML_1
# The task is binary_classification with evaluation metric f1
# AutoML will use algorithms: ['Decision Tree', 'Random Forest', 'Extra Trees', 'LightGBM', 'Xgboost', 'CatBoost', 'Neural Network', 'Nearest Neighbors']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree f1 0.0 trained in 6.48 seconds
# Adjust validation. Remove: 1_DecisionTree
# Validation strategy: 5-fold CV Shuffle,Stratify
# * Step simple_algorithms will try to check up to 3 models
# 1_DecisionTree f1 0.000603 trained in 10.11 seconds
# 2_DecisionTree f1 0.025361 trained in 8.85 seconds
# ...

# %%
pred = automl.predict(test)

# %%
sample = pd.read_csv(f'{path}/sample_submission.csv')
sample['전화해지여부'] = pred
sample.to_csv('automl_scaled.csv',index=False)
